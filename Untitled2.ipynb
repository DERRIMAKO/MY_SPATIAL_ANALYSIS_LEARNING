# %%
import pandas as pd
import geopandas as gpd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
hospitals = pd.read_excel("C:/Users/USER/Downloads/kenya-health-facilities-2017_08_02.xlsx", index_col = 0)

# %%
hospitals.head()
# Out:
#                                    Name Registration_number Keph level  \
# Code
# 22998               Kaka Medical Clinic                 NaN    Level 2
# 22985                KOPANGA DISPENSARY                 NaN    Level 2
# 22977           Fairview Medical Centre                 NaN    Level 2
# 22976  RADIANT GROUP OF HOSPITALS-UMOJA                 NaN    Level 3
# 22971             Songot Medical Clinic                 NaN    Level 2
#
#                                   Facility type  \
# Code
# 22998  Dispensaries and clinic-out patient only
# 22985        Basic primary health care facility
# 22977                  Secondary care hospitals
# 22976                  Secondary care hospitals
# 22971        Basic primary health care facility
#
#                                        Owner  \
# Code
# 22998  Private Practice - Medical Specialist
# 22985                     Ministry of Health
# 22977         Private Practice - Unspecified
# ...

# %%
hosi = pd.read_csv("C:/Users/USER/Downloads/Health_facilities_-4126638174547585951.csv")

# %%
hosi.head()
# Out:
#    FID  Facility Number                  Facility Name  HMIS Province  \
# 0    1                2          BARGONI HEALTH CENTRE  3606    COAST
# 1    2                3             FAZA HEALTH CENTRE   626    COAST
# 2    3                4            HINDI MAGOGONI DISP     0    COAST
# 3    4                5              HINDI PRISON DISP   615    COAST
# 4    5                6  HONGWE CATHOLIC HEALTH CENTRE   616    COAST
#
#   District   Division        LOCATION    Sub Location       Spatial_Re  \
# 0     LAMU      HINDI  HINDI MAGOGONI         BARGONI              DDP
# 1     LAMU       FAZA        TCHUNDWA        TCHUNDWA              DDP
# 2     LAMU      HINDI  HINDI MAGOGONI  HINDI MAGOGONI           DANIDA
# 3     LAMU      HINDI  HINDI MAGOGONI  HINDI MAGOGONI    ILRI VILLAGES
# 4     LAMU  MPEKETONI          HONGWE          HONGWE  SUBLOC CENTROID
#
#    Facility Type Agency  Latitude  Longitude  \
# 0              3    MOH -2.057423  40.795232
# ...

# %%
geometry = gpd.points_from_xy(hosi.Longitude, hosi.Latitude)

# %%
geo_df = gpd.GeoDataFrame(hosi, geometry=geometry)

# %%
geo_df.head()
# Out:
#    FID  Facility Number                  Facility Name  HMIS Province  \
# 0    1                2          BARGONI HEALTH CENTRE  3606    COAST
# 1    2                3             FAZA HEALTH CENTRE   626    COAST
# 2    3                4            HINDI MAGOGONI DISP     0    COAST
# 3    4                5              HINDI PRISON DISP   615    COAST
# 4    5                6  HONGWE CATHOLIC HEALTH CENTRE   616    COAST
#
#   District   Division        LOCATION    Sub Location       Spatial_Re  \
# 0     LAMU      HINDI  HINDI MAGOGONI         BARGONI              DDP
# 1     LAMU       FAZA        TCHUNDWA        TCHUNDWA              DDP
# 2     LAMU      HINDI  HINDI MAGOGONI  HINDI MAGOGONI           DANIDA
# 3     LAMU      HINDI  HINDI MAGOGONI  HINDI MAGOGONI    ILRI VILLAGES
# 4     LAMU  MPEKETONI          HONGWE          HONGWE  SUBLOC CENTROID
#
#    Facility Type Agency  Latitude  Longitude  \
# 0              3    MOH -2.057423  40.795232
# ...

# %%
geo_df.plot()
# Out:
# <Axes: >
