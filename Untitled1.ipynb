# %%
import pandas as pd
import geopandas as gpd
import folium
import geodatasets
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("C:/Users/USER/Downloads/archive (5)/volcano_data_2010.csv")

# %%
df1.head()
# Out:
#    Year  Month   Day  TSU   EQ                    Name              Location  \
# 0  2010      1   NaN  NaN  NaN              Tungurahua               Ecuador
# 1  2010      3  31.0  NaN  NaN        Eyjafjallajokull             Iceland-S
# 2  2010      5  27.0  NaN  NaN                  Pacaya             Guatemala
# 3  2010      5  29.0  TSU   EQ                 Sarigan  Mariana Is-C Pacific
# 4  2010      8   6.0  NaN  NaN  Karangetang [Api Siau]  Sangihe Is-Indonesia
#
#          Country  Latitude  Longitude  ...  TOTAL_DEATHS  \
# 0        Ecuador    -1.467    -78.442  ...           NaN
# 1        Iceland    63.630    -19.620  ...           2.0
# 2      Guatemala    14.381    -90.601  ...           1.0
# 3  United States    16.708    145.780  ...           NaN
# 4      Indonesia     2.780    125.480  ...           4.0
#
#   TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING TOTAL_MISSING_DESCRIPTION  \
# 0                      NaN           NaN                       NaN
# ...

# %% [markdown]
# ## We are going to keep the relevant columns

# %%
df = df1.loc[:, ["Year", "Name", "Country", "Latitude", "Longitude", "Type"]].copy()

# %%
df.head()
# Out:
#    Year                    Name        Country  Latitude  Longitude  \
# 0  2010              Tungurahua        Ecuador    -1.467    -78.442
# 1  2010        Eyjafjallajokull        Iceland    63.630    -19.620
# 2  2010                  Pacaya      Guatemala    14.381    -90.601
# 3  2010                 Sarigan  United States    16.708    145.780
# 4  2010  Karangetang [Api Siau]      Indonesia     2.780    125.480
#
#               Type
# 0    Stratovolcano
# 1    Stratovolcano
# 2  Complex volcano
# 3    Stratovolcano
# 4    Stratovolcano

# %%
geometry = gpd.points_from_xy(df.Longitude, df.Latitude)

# %%
geo_df = gpd.GeoDataFrame(df[["Year", "Name", "Country", "Latitude", "Longitude", "Type"]], geometry = geometry)

# %%
geo_df.head()
# Out:
#    Year                    Name        Country  Latitude  Longitude  \
# 0  2010              Tungurahua        Ecuador    -1.467    -78.442
# 1  2010        Eyjafjallajokull        Iceland    63.630    -19.620
# 2  2010                  Pacaya      Guatemala    14.381    -90.601
# 3  2010                 Sarigan  United States    16.708    145.780
# 4  2010  Karangetang [Api Siau]      Indonesia     2.780    125.480
#
#               Type                    geometry
# 0    Stratovolcano  POINT (-78.44200 -1.46700)
# 1    Stratovolcano  POINT (-19.62000 63.63000)
# 2  Complex volcano  POINT (-90.60100 14.38100)
# 3    Stratovolcano  POINT (145.78000 16.70800)
# 4    Stratovolcano   POINT (125.48000 2.78000)

# %%
world = gpd.read_file(geodatasets.get_path("naturalearth.land"))

# %% [markdown]
# #### We have:
# 1. The world dataset- we are going to use as a basemap
# 2. geo_df- the position of the volcanoes
# #### Now we Plot

# %%
fig, ax = plt.subplots(figsize = (24, 18));

world.plot(
    ax=ax,
    alpha = 0.4,
    color = 'grey',
    edgecolor = 'black'
)
geo_df.plot(
    ax=ax,
    column = 'Type',
    markersize = 50,
    legend = True
)

plt.title('VOLCANOES')
# Out:
# Text(0.5, 1.0, 'VOLCANOES')
